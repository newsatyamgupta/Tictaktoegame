# %% [markdown]
# ## DATA ANALAYTICS-->SUMMARIZING(MATHEMATICAL) OR GRAPHICAL(VISUALIZATION)

# %% [markdown]
# ## LIBRARY-->NUMPY(NUMERICAL+PYTHON)
#
# **USED FOR LINEAR ALGEBRA EQUATION AND CREATING HIGHER POWERFUL NTH DIMENSIONAL ARRAY
#
# **ARRAY-->COLLECTION OF HOMOGENOUS ELEMENTS

# %%
lst=[45,86,79,36,12,49,36]
lst
# Out:
# [45, 86, 79, 36, 12, 49, 36]

# %%
import numpy as np
np.array(lst)
# Out:
# array([45, 86, 79, 36, 12, 49, 36])

# %%
lst=[45,86,79,36,12,49,36,78.25]
lst
# Out:
# [45, 86, 79, 36, 12, 49, 36, 78.25]

# %%
array=np.array(lst)

# %%
lst=[45,86,79,36,12,49,36,78.25,"python"]
lst
# Out:
# [45, 86, 79, 36, 12, 49, 36, 78.25, 'python']

# %%
array=np.array(lst)

# %% [markdown]
# ## array attributes

# %%
array
# Out:
# array(['45', '86', '79', '36', '12', '49', '36', '78.25', 'python'],
#       dtype='<U32')

# %%
## shape--no of rows and columns
array.shape
# Out:
# (9,)

# %%
## size--total no of elements
array.size
# Out:
# 9

# %%
## dimension
array.ndim
# Out:
# 1

# %%
## dtype
array.dtype
# Out:
# dtype('<U32')

# %%
## itemsize--->memory allocation
array.itemsize
# Out:
# 128

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.size
# Out:
# 750

# %%
iris.ndim
# Out:
# 2

# %%
iris.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12208\296369552.py in ?()
# ----> 1 iris.dtype
#
# C:\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
iris.dtypes

# %%
iris.itemsize

# %% [markdown]
# ## difference between list and array
#
# **list contain element in the form of heterogenous but array stored homogenous element
#
# **list contain more memory than array
#
# **array works faster than list
#
# ** array more compact than list

# %%
lst=[48,65,96,85,78,12,14,15,36,59]
lst

# %%
lst+2

# %%
for i in lst:
  print(i+2,end=",")

# %%
[i+2 for i in lst]

# %%
##
array=np.array([45,69,36,45,87,25,16,96,78,36])
array+2

# %%
array-2

# %%
array*2
array

# %%
## assignment operators
array+=2
array

# %%
price=np.array([45,69,78,32.25,48.36,49,25,24,28])
quantity=np.array([2,3,4,5,6,1,2,3])
price+quantity

# %%
price=np.array([45,69,78,32.25,48.36,49,25,24,28])
quantity=np.array([2,3,4,5,6,1,2,3,6])
price+quantity

# %%
np.concatenate([price,quantity],axis=0)

# %%
sum([price,quantity])

# %%
np.sum((price,quantity),axis=0)

# %%
np.sum((price,quantity),axis=1)

# %%
np.power([price,quantity],2)

# %%
price=np.array([45,69,78,32.25,48.36,49,25,24,28])
quantity=np.array([2,3,4,5,6,1,2,3])
np.sum([price,quantity],axis=0)

# %%
np.concatenate([price,quantity])

# %%
## indexing and slicing
price[5:]

# %% [markdown]
# ## 2d operations-->

# %%
lst=range(1000000)
array=np.arange(10000000)

# %%
## time complexity
import time
start_time=time.time()
lst=[i+2 for i in lst]
end_time=time.time()
print(end_time-start_time)

# %%
import time
start_time=time.time()
array=array+2
end_time=time.time()
print(end_time-start_time)

# %% [markdown]
# ## function to create a 2 dimensional array

# %%
## np.arange
array=np.arange(10,50,2)
array

# %%
## convert to two dimension
array=np.arange(10,50).reshape(8,5)
array

# %%
array=np.arange(10,50).reshape(8,6)
array

# %%
## random.random-->it returns random number between 0 to 1,half open interval(it includes 0 but exclude 1)

# %%
np.random.random()

# %%
np.random.random(5)

# %%
np.random.random((5,4))

# %%
## np.random.randint
np.random.randint()

# %%
np.random.randint(10)

# %%
np.random.randint(10,40,(4,10))

# %%
## np.random.randn-->return normal distributioon value(-3,3)
np.random.randn(10)

# %%
array1=np.arange(10,30).reshape(5,4)
array2=np.arange(30,50).reshape(5,4)
array1,array2

# %%
array1+array2

# %%
np.concatenate([array1,array2],axis=1)

# %%
np.sum([array1,array2],axis=0)

# %%
np.sum([array1,array2],axis=1)

# %%
array1+=5
array1

# %%
## indexing and slicing in two dimensions
array1[2,1]

# %%
array1[3,1:3]

# %%
array1[2:4,1:3]

# %%
array1[4,3]+=6
array1

# %% [markdown]
# ## conditional statement
# marks=np.arange(30,95,3)

# %%
marks=np.arange(30,95,3)
marks

# %%
marks[marks>=70]

# %%
marks[marks>=70 & marks<80 ]

# %%
marks[(marks>=70) & (marks<80) ]

# %%
marks[70<=marks<=80]

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips.head()

# %%
tips[(tips.total_bill>30) & (tips.sex=="Female") | (tips.time=="Dinner")]

# %%
## np.where
np.where(marks%2==0,marks,0)

# %%
tips[np.where(tips.iloc[:,-1]>=4)]

# %%
np.where(tips["size"]%2==0)

# %%
np.where(tips["size"]>4,tips["size"],0)

# %% [markdown]
# ## STACKING-->

# %%
import numpy as np
array=np.arange(10,30)
array1=np.arange(30,50)
array,array1

# %%
np.concatenate([array,array1])

# %%
np.stack([array,array1],axis=2)

# %%
np.hstack([array,array1])

# %%
np.vstack([array,array1])

# %%
np.dstack([array,array1])

# %% [markdown]
# ## PANDAS--->
#
# ## THERE ARE TWO DATA STRUCTURE-->
#
# **pANDAS SERIES-->CONTAIN ONE DIMENSIONAL DATA WITH MIXED DATA TYPES
#
# **PANDAS SATAFRAME-->CONTAIN DATA IN TABULAR REPRESENTATION.

# %%
import pandas as pd
dictionary={"python":87,"c":56,"ml":96,"ai":87}
pd.Series(dictionary)

# %%
lst=[15,69,35,48,75,96,3,65]
pd.Series(lst)

# %%
subject=["python","c","ml","ai"]
marks=[45,96,58,78]
gpa=(4.5,6.5,3.6,8.3)
pd.Series(subject,index=marks)

# %% [markdown]
# ## crisp dm-->
#
# -->business understanding(problem statment)
#
# -->data understanding
#
# -->data preprocessimg
#
# -->modelling
#
# -->evaluation
#
# -->deployment

# %%
## data
import pandas as pd
import numpy as np
stroke_df=pd.read_csv("/content/Stroke.csv.zip")
stroke_df.head()

# %%
## CREATE A COPY OF DATASET
stroke_df1=stroke_df.copy()
stroke_df1.head()

# %%
stroke_df2=stroke_df.sample(1000)

# %%
stroke_df.dtypes

# %%
## to see last five data
stroke_df.tail()

# %%
stroke_df.sample(5)

# %%
type(stroke_df)

# %%
type(stroke_df.Ever_Married)

# %%
stroke_df.dtypes

# %%
stroke_df.info()

# %% [markdown]
# ## DATA PREPROCESSING-->

# %% [markdown]
# ## to check the duplication in data

# %%
stroke_df.duplicated().sum()

# %%
## changing the data types
stroke_df.Age=stroke_df.Age.astype(int)

# %%
stroke_df

# %% [markdown]
# ## REMOVING INSIGNIFICANT COLUMNS-->

# %%
stroke_df.drop(columns=["ID"],inplace=True)

# %% [markdown]
# ## statistical inference-->

# %%
stroke_df.describe()

# %%
stroke_df.describe(include=object)

# %% [markdown]
# ## checking null values

# %%
stroke_df.isnull().sum()

# %%
## checking data distributions
stroke_df.BMI.plot(kind="kde")

# %%
## replace value with mean,median,mode
stroke_df.BMI.median()

# %%
stroke_df.BMI.mode()[0]

# %%
stroke_df.BMI.fillna(stroke_df.BMI.mode()[0],inplace=True)

# %%
stroke_df.Smoking_Status.mode()[0]

# %%
stroke_df.Smoking_Status.fillna(stroke_df.Smoking_Status.mode()[0],inplace=True)

# %%
stroke_df.isnull().sum()

# %% [markdown]
# ## indexing and slicing

# %%
stroke_df[50:80]

# %%
stroke_df[50:80,["Gender","Stroke"]]

# %%
stroke_df.loc[50:80,["Gender","Stroke"]]

# %%
stroke_df.loc[50:80,1:4]

# %%
stroke_df.iloc[50:80,1:4]

# %%
stroke_df.tail(1)

# %%
stroke_df.Smoking_Status.value_counts()

# %% [markdown]
# ## adding more rows in dataset

# %%
stroke_df.columns

# %%
stroke_df[43400]=["Female",35,1,0,"NO","Private","Rural",90.26,25.36,"formerly smoked",0]

# %%
stroke_df.loc[43400]=["Female",35,1,0,"NO","Private","Rural",90.26,25.36,"formerly smoked",0]

# %%
stroke_df.tail(1)

# %% [markdown]
# ## concatenate-->combine two or more dataset into one

# %%
pd.concat([stroke_df,stroke_df2],axis=1)

# %% [markdown]
# ## merge-->merging two table into one based on common column

# %%
pd.merge(left=stroke_df,right=stroke_df2)

# %%
# create a DataFrame from a dictionary
import pandas as pd
df_prof_info_A = pd.DataFrame({
   'Emp_ID': [1001,1002,1003,1004,1005],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Stephan'],
   'Gender':['M', 'F', 'M', 'F', 'M'],
   'Company':['Apple','Walmart','Intel','Cummins','Ford'],
   'Salary':[67000,90000,87000,69000,78000]},
   index=[101,102,103,104,105])

# print the DataFrame
print("The first DataFrame is : \n",df_prof_info_A)

print("\n\n")

# create a DataFrame from a dictionary
df_prof_info_B = pd.DataFrame({
    'Emp_ID': [1006,1007,1008,1009,1010,1011],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty','James'],
    'Gender':['M', 'M', 'M', 'F', 'F','M'],
   'Company':['Cognizant','Apple','Intel','Cummins','Walmart','Intel'],
   'Salary':[89000,80000,79000,97000,88000,89000]},
   index=[106,107,108,109,110,111])

# print the DataFrame
print("The second DataFrame is : \n",df_prof_info_B)

print("\n\n")

# create a DataFrame from a dictionary
df_pers_info_A = pd.DataFrame({
     'Emp_ID': [1001,1002,1003,1004,1005],
   'Hometown': ['New York', 'London', 'San Francisco', 'Seattle', 'Madrid'],
     'Gender':['M', 'F', 'M', 'F', 'M'],
    'Marital':['Married','Divorsed','Single','Married','Single'],
   'Dependents':[1,1,3,2,1]},
   index=[101,102,103,104,105])

# print the DataFrame
print("The third DataFrame is : \n",df_pers_info_A)

print("\n\n")

# create a DataFrame from a dictionary
df_pers_info_B = pd.DataFrame({
     'Emp_ID': [1006,1007,1009,1010,1011,1012],
   'Hometown': ['Paris', 'Boston', 'San Francisco', 'Seattle', 'London','London'],
    'Marital':['Married','Divorsed','Single','Married','Single','Single'],
   'Dependents':[1,1,3,2,1,2]},
   index=[101,102,103,104,105,106])

# print the DataFrame
print("The fourth DataFrame is : \n",df_pers_info_B)

# %%
pd.concat([df_prof_info_A,df_prof_info_B])

# %%
pd.concat([df_prof_info_A,df_prof_info_B],axis=1)

# %%
pd.merge(df_prof_info_A,df_pers_info_A,on=["Emp_ID","Gender"])

# %% [markdown]
# ## Append-->

# %%
df_prof_info_A._append(df_prof_info_B)

# %%
select*,account.account_no from customer_id left join account on
customer_id.cust_no=account.cust_no left join transaction on account.account_no=
transaction.acct_no

# %% [markdown]
# ## pivot table--

# %%
pd.pivot_table(stroke_df,index=["Gender","Stroke"],values="BMI")

# %%
pd.pivot_table(stroke_df,index=["Gender","Stroke"],values="BMI",aggfunc=len)

# %%
stroke_df.head()

# %%
stroke_df.Work_Type.value_counts()

# %%
pd.pivot_table(stroke_df,index=["Gender","Residence_Type"],values="Stroke",aggfunc=len)

# %%
pd.pivot_table(stroke_df,index=["Gender"],columns="Residence_Type",values="Stroke",aggfunc=len)

# %% [markdown]
# ## crosstable

# %%
pd.crosstab(stroke_df.Gender,stroke_df.Ever_Married)

# %%
pd.crosstab(stroke_df.Gender,stroke_df.Hypertension).plot(kind="bar")

# %%
pd.crosstab(stroke_df.Gender,stroke_df.Hypertension,values=stroke_df.Age,aggfunc=np.mean)

# %%
pd.pivot_table(stroke_df,index=["Gender"],columns=["Hypertension"],values=["Age"],aggfunc=np.mean)

# %% [markdown]
# ## map and replace-->

# %%
stroke_df.Work_Type.value_counts()

# %%
## MAP-->
stroke_df["activity"]=stroke_df.Work_Type.map({"Private":"Moderate","Govt_job":"moderate","children":"low activity","Never_worked":"low activity","Self-employed":"high"})

# %%
stroke_df.head()

# %%
stroke_df.Work_Type=stroke_df.Work_Type.map({"Private":0,"Govt_job":1,"children":2,"Never_worked":2,"Self-employed":3})

# %%
stroke_df.head()

# %%
stroke_df.Smoking_Status.replace({np.nan:""})

# %% [markdown]
# ## GROUPBY

# %%
stroke_df.groupby("Gender")["Smoking_Status"].nunique()

# %%
stroke_df.groupby(["Gender","Ever_Married"])["Stroke",].count()

# %%
stroke_df.head()

# %% [markdown]
# ## Visualization---->matplotlib,seaborn,plotly

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
plt.scatter(stroke_df.Age,stroke_df.BMI)

# %%
sns.heatmap(stroke_df.corr(),annot=True)

# %%
num_cols=stroke_df.select_dtypes(np.number)
cat_cols=stroke_df.select_dtypes(object)
num_cols.columns,cat_cols.columns

# %%
sns.heatmap(num_cols.corr(),annot=True)

# %%
sns.pairplot(num_cols)

# %%
sns.barplot(x="Stroke",y="Age",data=stroke_df)

# %%
sns.boxplot(x="Stroke",y="Age",data=stroke_df,hue="Gender")

# %%
x=list(num_cols.columns)
for i in x:
    sns.barplot(x="Stroke",y=i,data=stroke_df)
    plt.show()

# %%
for i in stroke_df.columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x="Stroke", y=i, data=stroke_df)
    plt.title(f"Boxplot of {i} vs Stroke")
    plt.show()
